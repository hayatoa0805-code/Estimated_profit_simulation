# %%
import math


pre_cost = 2000 * 1.0E+4
fix_cost = 1000 * 1.0E+4
cost = pre_cost + fix_cost


def calc_earnings(pre_cost):
    earnings = 2.87E+7 * math.log(pre_cost) - 4.44E+8
    return int(earnings)


def calc_profit(earnings, cost):
    profit = earnings - cost
    return int(profit)


earnings = calc_earnings(pre_cost)
profit = calc_profit(earnings, cost)
profit_ratio = int(profit / cost * 100)

data_ad_cost = list(range(1000, 9001, 1))
data_earnings = [calc_earnings(ad_cost*1.0E+04) for ad_cost in data_ad_cost]
data_profit = [
    calc_profit(earnings, ad_cost*1.0E+04 + fix_cost) for earnings, ad_cost in zip(data_earnings, data_ad_cost)]

max_profit = max(data_profit)
best_ad_cost = data_ad_cost[data_profit.index(max_profit)]
# Out:
# /var/folders/mx/k3s5q_2j3336m04_sv2mv6q40000gn/T/ipykernel_1490/2255036377.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
import streamlit as st

st.title('予想収益シミュレーション')
st.sidebar.write('##入力フォーム')
st.sidebar.write('広告費（万円', 1000, 9000)

ad_cost = st.sidebar.slider('広告費', 1000, 9000)
fix_cost = 1.0E+04
cost = ad_cost * fix_cost
st.write(f'宣伝広告費 {ad_cost}')
# Out:
# 2025-11-18 11:49:38.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 11:49:38.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run app-4.py
# Out:
#       👋 Welcome to Streamlit!
#
#       If you'd like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email:  ^C
